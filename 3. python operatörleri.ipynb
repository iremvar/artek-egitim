# %%
# Atama Operatörleri

# x = 5
# y = 10
# z = 20

# x, y, z = 5, 16, 20 # böyle de yazabiliriz

# x, y = y, x # x yye y xe esit olur

# x = x + 5 # xe bes ekler yeni xi bulur
# x += 5 # xe beş ekler
# x -= 5 # xten bes cıkarır
# x *= 5 # xi besle carpar
# x/= 5 # xi bese boler
# x %= 5 # modunu alır
# y //= 5 # yyi bese boler (sadece tam sayı yazar)
# y **= 5 # y üzeri beş


# print(x, y, z)

'''
values = 1, 2, 3 

print(values)
print(type(values))

x, y, z = values

print(x, y, z)

'''

'''
values = 1, 2, 3 , 4, 5

print(values)
print(type(values))

x, y, z = values

print(x, y, z) #3ten fazla eleman oldugu icin hata verir

'''

'''
values = 1, 2, 3 , 4, 5

print(values)
print(type(values))

x, y, *z = values #son 3 elemanı da zye liste olarak atar eger tek eleman istersek znin kacıncı indeksiyse onu yazmamız gerekir

print(x, y, z) 

'''

# %%
# Demo : Atama Operatörleri

# x, y, z = 2, 5, 10

# numbers = 1, 5, 7, 10, 6

# 1- Kullanıcıdan aldığınız 2 sayının çarpımı ile x, y, z toplamının farkı nedir?

# a = int(input("birinci sayıyı giriniz: "))
# b = int(input("ikinci sayıyı giriniz: "))

# result = (a*b) - (x+y+z)


# 2- y'nin x'e kalansız bölümüni hesaplayınız.

# result = y // x

# 3- (x, y, z) toplamının mod 3'ü nedir?

# toplam = x+y+z
# result = toplam % 3

# 4- y'nin x. kuvvetini hesaplayınız.

# result = y ** x

# 5- x, *y, z = numbers işlemine göre z'nin küpü kaçtır?

# x, *y, z = numbers 
# result = z ** 3

# 6- x, *y, z = numbers işlemine göre y'nin değerleri toplamı kaçtır?
# x, *y, z = numbers 
# result = y[0] + y[1] + y[2]

# print(result)

# %%
# Karşılaştırma Operatörleri

# a, b, c, d = 5, 5, 10, 4

# password = '1234'
# username = 'sadikturan'
 
# result = (a==b)  # a ve b esit mi?? true
# result = (a==c) #false
# result = 'sdktrn' == username
# result = 'sadikturan' == username

# result = (a != b) #a ve b eşit değil mi? false
# result = (a != c) #true
# result = (a > c) # a cden büyük mü? false
# result = (a < c) # a cden küçük mü? true
# result = (a >= b) #a bden büyük eşit mi? true

# result = (True == 1) #true
# result = (False == 0) #true

# print(result)

# %%
# Demo : Karşılaştırma Operatörleri

# 1- Girilen 2 sayıdan hangisi büyüktür?

# a = int(input("a: "))
# b = int(input("b: "))

# result = a > b
# print(f'a: {a} b: {b} den büyüktür: {result}')

# 2- Kullanıcıdan 2 vize (%60) ve final (%40) notunu alıp ortalama hesaplayınız. Eğer ortalama 50 ve üstündeyse geçti, değilse kaldı yazdırın.

# vize1 = float(input("1. vize: "))
# vize2 = float(input("2. vize: "))
# final = float(input("final: "))

# ortalama = ((vize1 + vize2) / 2 * 0.6) + (final * 0.4)
# print(f"not ortalamanız: {ortalama} ve dersten gecme durumunuz : {ortalama >= 50} ")

# 3- Girilen bir sayının tek mi çift mi olduğunu yazdırın.

# sayi = int(input( "sayı: "))

# tekcift = (sayi % 2 == 0)

# print(f' cift olma durumu: {tekcift}')

# 4- Girilen bir sayının negatif pozitif durumunu yazdırın.

# sayi = int(input( "sayı: "))

# pozitif = (sayi > 0)

# print(f' pozitif olma durumu: {pozitif}')

# 5- Parola ve email bilgisini isteyip doğruluğunu kontrol ediniz. 
# (email: email@sadikturan.com parola:abc123)

# email = 'email@sadikturan.com'
# password = 'abc123'

# girilenEmail = input("e mail: ")
# girilenPassword = input("password: ")


# isEmail = (email==girilenEmail )
# isPassword = (password==girilenPassword)

# print(f' Email bilgisi doğru mu: {isEmail} ve girilen parola doğru mu: {isPassword} ')

# %%
# Mantıksal Operatörler

# x = 5
# hak = 5
# devam = 'e'
# result = 5 < x < 10 #false 

# AND

# result = (x > 5) and (x < 10) # false , true => false
# result = (hak > 0 and (devam == 'e')) 


# OR

# result = (x > 0) or ( x % 2 == 0) 
# true, false => true
# false, false => false
# true, true => true


# NOT

# result = not(x > 0)  #cevabı tersine çevirir

#x, 5-10 arasında olan bir çift sayı mı?

# result = (x > 5) and (x < 10) and (x & 2 == 0)

# print(result)

# %%
# Demo: Mantıksal Operatörler

# 1- Girilen bir sayının 0-100 arasında olup olmadığını kontrol ediniz.

# a = float(input("Bir sayı giriniz: "))

# result = (a > 0) and (a < 100)

# 2- Girilen bir sayının pozitif çift sayı olup olmadığını kontrol ediniz.

# a = float(input("Bir sayı giriniz: "))

# result = (a > 0) and (a % 2 == 0)

# 3- Email ve parola bilgileri ile giriş kontrolü yapınız.

# email = 'email@sadikturan.com'
# password = 'abc123'

# girilenEmail = input("e mail: ")
# girilenPassword = input("password: ")


# result = (email==girilenEmail ) and (password==girilenPassword)

# 4- Girilen 3 sayıyı büyüklük olarak karşılaştırınız.

# a = int(input("1. sayı: "))
# b = int(input("2. sayı: "))
# c = int(input("3. sayı: "))

# result = (a > b) and (a >  c)
# print(f'a en büyük sayıdır: {result}')

# result = (b > a) and (b > c)
# print(f'b en büyük sayıdır: {result}')


# result = (c > a) and (c > b)
# print(f'c en büyük sayıdır: {result}')

# 5- Kullanıcıdan 2 vize (%60) ve final (%40) notunu alıpp ortalama hesaplayınız.
# Eğer ortalama 50 ve üstündeyse geçti, değilse kaldı yazdırınız.
# a-) Ortalama 50 olsa bile final notu en az 50 olmalıdır.
# b-) Finalden 70 alındıgında ortalamanın önemi olmasın

# vize1 = int(input("1. vize: "))
# vize2 = int(input("2. vize: "))
# final = int(input("Final: "))
# ortalama = ((vize1 + vize2 )//2 *0.6) + (final * 0.4)
# # result = (ortalama>=50) and ( final >=50)
# # result = (ortalama>=50) or ( final >=70)


# print(f'öğrencinin ortalaması : {ortalama} ve geçme durumu : {result}')

# 6- Kişinin ad, kilo ve boy bilgilerini alıp kilo indekslerini hesaplayınız.
# Formül : (Kilo/boy uzunlugunun karesi)
# Aşağıdaki tabloya göre kişi hangi gruba girmektedir.

# 0-18.4 => zayıf
# 18.5-24.9=> Normal
# 25.0-29.9 => Fazla kilolu
# 30.0-34.9=> Şişman(obez)

# name = input("adınız: ")
# kg = float(input("kilo: "))
# hg = int(input("boy: "))

# index= kg // (hg ** 2 )

# zayif= index >=0 and index<=18.4
# normal= index >=18.5 and index<=24.9
# fazlakilolu = index >=25.0 and index<=29.9
# obez= index >=30.0 and index<=34.9
# print(f'{name}kilo indeksin : {index} ve kilo değerlendirmen zayif: {zayif} ')
# print(f'{name}kilo indeksin : {index} ve kilo değerlendirmen normal : {normal} ')
# print(f'{name}kilo indeksin : {index} ve kilo değerlendirmen fazla kilolu: {fazlakilolu} ')
# print(f'{name}kilo indeksin : {index} ve kilo değerlendirmen şişman: {obez} ')

# print(result)

# %%
# Identity Operator : is

# x = y =[1, 2, 3]
# z =[1, 2, 3]

# print(x==y)
# print(x==z)
# print(x is y) #true #referans karsılastırması
# print(x is z) #false

# x =[1, 2, 3]
# y =[2, 4]

# del x[2]
# y[1] = 1
# y.reverse()

# print(x==y)
# print(x is y)
# print(x is not y)

# görüntü olarak aynı listeler ama referans farklı 


# Membership Operators : in

# x = ['apple', 'banana']
# print('banana' in x) #banana listede var mı

# name = 'Çınar'
# print('a' in name)
# print('a' not in name)
