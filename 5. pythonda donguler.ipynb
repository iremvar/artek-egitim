# %%
# For Döngüleri

# numbers = [1, 2, 3, 4, 5]

# for num in numbers:
#     print(num)  #tek tek yazmak icin 


# names = ['çınar', 'sadık', 'sena']

# for name in names:
#     print(name)
    
# name = 'sadik turan'

# for n in name:
#     print(n) #str ifadenin her karakteri yazdırılır

# tuple = (1, 2, 3, 4, 5)

# for t in tuple:
#     print(t)
    
# tuple = [(1, 2), (1, 3), (3, 5), (5, 7)]

# for (a, b) in tuple:
#     print(a) #sadece aları yazar

# d = {'k1': 1, 'k2':2, 'k3':3}
# for item in d:
#     print(item)
    
# for item in d.items():
#     print(item)

# for key, value in d.items():
#     print(key)

# %%
# Demo: For Döngüleri

# sayilar = [1,3,5,7,9,12,19,21]

#1

# for sayi in sayilar:
#     if sayi%3 ==0:
#         print(sayi)

#2

# toplam = 0
# for sayi in sayilar:
#     toplam = toplam + sayi
# print(toplam)

#3

# for sayi in sayilar:
#    if sayi % 2 == 1:
#        print(sayi ** 2)
    
    
#4

# sehirler = ['kocaeli', 'istanbul', 'ankara', 'izmir', 'rize']

# for sehir in sehirler:
#     if len(sehir)>5:
#         print(sehir)

# for sehir in sehirler:
#     if len(sehir)<=5:
#         print(sehir)


urunler = [
    {'name': 's6' , 'price': '3'},
    {'name': 's7' , 'price': '4'},
    {'name': 's8' , 'price': '5'},
    {'name': 's9' , 'price': '6'} ,       
    {'name': 's10' , 'price': '7'}   
]

#5

# toplam = 0

# for urun in urunler:
#     fiyat = int(urun['price'])
#     toplam = toplam + fiyat
# print(toplam)
    
#6
# for urun in urunler:
#   if ( int(urun['price']) <= 5):
#     print(urun['name'])

# %%
# While Döngüleri

# 1den 100e kadar

x = 0
while x < 100:
    print(x)
    x=x+1
    
print('bitti')
