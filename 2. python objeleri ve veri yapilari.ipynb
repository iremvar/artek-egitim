# %%
# Pythonda Sayı Veri Tipleri
# int #tam sayilar icin
# float #ondalikli sayilar icin

# Matematiksel Operatorler
# ** bir sayinin ussunu almak icin
# % mod alirken kullanilir
# / bolme isleminde kullanilir
# // bolme isleminde ondalik kismi gostermez, bir alt sayiya yuvarlar

# %%
# Degisken Tanimlama

# Rakamla başlayamaz
# Büyük küçük harf duyarlılığı vardır age Age farklıdır
# Türkçe karakter kullanılmaz

# x = 1                 # int
# y = 2.3               # float
# name = "Çınar"        # string
# isStudent = True       # bool

# a = '10'
# b = '20'
# print(a+b)   # tırnak oldugu icin metin olarak birlestirilir

# firstName = "Sadık"
# lastName = " Turan"

# print (firstName + lastName)

# %%
# Veri Tipi Dönüşümleri

# x = input('1.sayi: ')
# y = input('2.sayi: ')

# toplam = x + y

# print(toplam)

# x ve yyi string olarak kabul ettigi icin 10+20=1020 olur, veri tipi değişmemiz gerekir

# x = input('1.sayi: ')
# y = input('2.sayi: ')

# print(type(x))
# print(type(y))

# toplam = int(x) + int(y)

# print(toplam)

# x = 5      #int
# y = 2.5    #float
# name = 'Çınar' #string
# isOnline = True #bool

# print(type(x))
# print(type(y))
# print(type(name))
# print(type(isOnline))

# Type Conversion

# int to float

# x = float(x)
# print(x)
# print(type(x))

# float to int

# y = int(y)
# print(y)
# print(type(y))

# result = x + y
# print(result)
# print(type(result))
# print(x)
# print(y)

# bool to str

# isOnline = str(isOnline)
# print(isOnline)
# print(type(isOnline))

# bool to int

# isOnline = int(isOnline)
# print(isOnline)
# print(type(isOnline))
# Out:
# 1
# <class 'int'>

# %%
# Veri Tipi Dönüşümleri örnek

# r = float(input('yarı çap: '))

# pi = 3.14


# alan = 2 * pi * r**2
# cevre = 2 * pi * r
# print("alan", alan)
# print("çevre", cevre)

# %%
# Karakter Dizlieri : String

# name = "Sadık"
# surname = "Turan"
# age = '36' #sayı oldugu icin stringe cevirmemiz gerekiyor ya da tırnak icine alırız

# print("My name is " + name + ' ' + surname + ' and \nI am ' + age + ' years old')  #\n alt satıra gecer

# name = "Sadık"
# surname = "Turan"
# age = 36

# greeting = "My name is " + name + ' ' + surname + ' and \nI am ' + str(age) + ' years old'
# # length = len(greeting)

# #print(greeting)
# # print(greeting[0]) #ilk haneyi yazar
# # print(len(greeting)) # kac haneli oldugunu yazar

# # print(greeting[length-1]) #son hanesini yazması için once length atadık ve sondan 1. için -1 yazdık
# # print(greeting[-1]) #uzun uzun yazmamak için boyle de yapılabilir

# # print(greeting[3:7]) #3ten 7ye kadar yazar
# print(greeting[3:]) #bitiş yazılmazsa sonuna kadar yazar
# print(greeting[:16]) #başlangıç yazmazsa en baştan başlar
# print(greeting[2:40:2]) #2den 40a kadar yazar ama 2 hanede bir tane yazar

# %%
# String Formatlama

# name = 'Çınar'
# surname = 'Turan'
# age = 36

# print ('My name is {} {}' .format(name, surname))
# print ('My name is {0} {1}' .format(name, surname)) #aynı sıtayla yazar
# print ('My name is {1} {0}' .format(name, surname)) #yer değiştirip yazar
# print ('My name is {s} {n}' .format(n=name, s=surname)) #yer degistirip yazar
# print ('My name is {} {} and I am {} years old' .format(name, surname ,age))


# result = 200 / 700
# print('the result is {r:1.3}' .format(r=result))

# print(f"My name is {name} {surname} and I'm {age} years old.")

# %%
# # Demo: Strings

# website = "http://www.sadikturan.com"
# course = "Python Kursu: Baştan Sona Python Programlama Rehberiniz (40 saat)"

# # 1- 'course' karakter dizisinde kaç karakter bulunmaktadır?

# print (len(course))

# # 2- 'website' içinden www karakterlerini alın.

# print (website[7:10])

# # 3- 'website' içinden com karakterlerini alın.

# print (website[22:25])
# print (website[length-3:length])

# # 4- 'course' içinden ilk 15 ve son 15 karakterlerini alın.
# print (course[:15])
# print (course[-15:])

# # 5- 'course' ifadesindeki karakterleri tersten yazdırın.

# print (course[::-1])


# name, surname, age, job ='Bora', 'Yılmaz', 32 , 'Mühendis'

# # 6- Yukarıda verilen değişkenler ile ekrana aşağıdaki ifadeyi yazdırın.
# # 'Benim adım Bora Yılmaz, Yaşım 32 ve mesleğim mühendis.'

# print (f"Benim adım {name} {surname}, Yaşım {age} ve mesleğim {job}" )

# # 7- 'Hello world' ifadesindeki w harfini 'W' ile değiştirin.

# s = 'Hello world'

# s= s[0:6] + 'W' + s[-4:]

# print(s)

# # 8- 'abc' ifadesini yan yana 3 defa yazdırın.

# print ('abc' * 3 )

# %%
# String Metotları

# message = 'Hello there. My name is Sadık Turan.'

# message = message.upper()  # bütün harfleri büyük harfe dönüştürür
# message = message.lower()  # bütün harfleri küçük harfe dönüştürür
# message = message.title()  # bütün baş harfleri büyük harfe dönüştürür
# message = message.capitalize()  # sadece ilk harfi büyük harfe dönüştürür
# message = message.strip()  # baştaki boşluk karakteri gider


# message = message.split()  # bütün kelimeleri boşluklardan itibaren ayırır
# print(message[2]) # 2. kelimeyi yazdırır

# message = message.split('.') # kelimeyi noktadan ayırır
# message = ' '.join(message) #aralara boşluk koyarak birleştirir


# index = message.find('Sadık')
# print(index) #aradığımız kelimenin hangi harften itibaren oldugunu gosterir, eğer -1 verirse yok demek

# isFound = message.startswith('H')
# print(isFound) #cumlenin ilk karakterini dogrulamak icin kullanılır

# isFound = message.endswith('.')
# print(isFound) #cumlenin son karakterini dogrulamak icin kullanılır

# message = message.replace('Sadık','Çınar') #cümlede sadık yerine çınar yazar
# message = message.replace(' ', '*')

# message = message.center(100) #100 karakterlik bir alanda yazıyı ortalar.
# message = message.center(50, '*') #50 karakterlik bir alanda yazıyı ortalar geri kalan kısmı * ile tamamlar

# print(message)

# %%
# # Demo: String Metotları

# website = "http://www.sadikturan.com"
# course = "Python Kursu: Baştan Sona Python Programlama Rehberiniz (40 saat)"

# # 1- ' Hello World ' karakter dizisinin baş ve sondaki boşluk karakterlerini silin.

# result = ' Hello World '.strip()
# result = ' Hello World '.lstrip()  #soldan bir karakter siler
# result = ' Hello World '.rstrip()  #sağdan bir karakter siler

# result = website.strip('/:pth') #yazılı karakterleri siler

# # 2- 'www.sadikturan.com' içindeki sadikturan bilgisi haricindeki her karakteri silin.

# result = 'www.sadikturan.com'.strip('w.com')

# # 3- 'course' karakter dizisinin tün karakterlerini küçük harf yapın

# result = course.lower()

# # 4- 'website' içinde kaç tane a karakteri vardır? (count('a'))

# result = website.count('a')

# # 5- 'website' www ile başlayıp com ile bitiyor mu?

# result = website.startswith('www')
# result = website.endswith('com')

# # 6-  'website' içinde '.com' ifadesi var mı?

# result = website.find('.com')
# result = website.find('.com',0,10) #ilk 10 karakter içerisinde arar
# result = website.rfind('Python') #aramaya sondan başlar

# result = website.index('com')
# result = website.rindex('com') #aramaya sondan başlar yoksa hata verir

# # 7- 'course' içindeki karakterlerin hepsi alfabetik mi? (isalpha, isdigit)

# result = course.isalpha() #alfabetik mi
# result = course.isdigit() #rakam mı


# # 8- 'Contents' ifadesini satırda 50 karakter içine yerleştirip sağ ve soluna * ekleyiniz

# result = 'Contents'.center(50, '*')
# result = 'Contents'.ljust(50, '*') #sola yaslar
# result = 'Contents'.rjust(50, '*') #sağa yaslar


# # 9- 'course' karakter dizisindeki tüm boşluk karakterlerini '-' ile değiştirin

# result = course.replace(' ', '-')
# result = course.replace(' ', '-',5) #5 karakteri değiştirir

# # 10- 'Hello World' karakter dizisinin 'World' ifadesini 'There' olarak değiştirin

# result = 'Hello World'.replace('World','There')

# # 11- 'course' karakter dizisini boşluk karakterlerinden ayırın

# result = course.split()
# result =result[2]  #2. ifadeyi yazar

# print(result)

# %%
# Pythonda Listeler

# message = 'Hello There. My name is Sadık Turan'.split()
# # print(message[0])

# # my_list = [1,2,3]  #liste tanımlama
# # my_list = ['bir',2, True, 5.6]

# # print(my_list)

# list1 = ['one', 'two', 'three']
# list2 = ['four', 'five', 'six']

# numbers = list1 +list2
# print(numbers)
# print(len(numbers)) #kaç tane olduğunu yazar
# print(message[0])
# print(numbers[2])

# userA = ['Sadık',36]
# userB = ['Çınar', 2]

# users = (userA, userB)

# print(userA)
# print(userB)
# print(users)

# a = users[0]
# print(a[0])

# %%
# # Demo : Listeler

# # 1- "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir listeoluşturunuz

# list1 = ['Bmw','Mercedes','Opel','Mazda']
# result = list1

# # 2- Liste kaç elemanlıdır?

# result = len(list1)

# # 3- Listenin ilk ve son elemanı nedir?

# result = (list1[0] + ' ve ' + list1[-1])

# # 4- Mazda değerini Toyota ile değiştirin

# # list1[3] = 'Toyota'
# # result = list1

# # 5- Mercedes listenin bir elemanı mıdır?

# result = 'Mercedes' in list1 #içinde midir?

# # 6- Listenin -2 indeksindeki değer nedir?

# result = list1[-2]

# # 7- Listenin ilk 3 elemanını alın

# result = list1[0:3]

# # 8- Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin

# # list1[-2] = 'Toyota'
# # list1[-1] = 'Renault'
# # ya da
# # list1[-2:] = ['Toyota', 'Renault']

# # result = list1

# # 9- Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.

# result = (list1 + ['Audi','Nissan'])

# # 10- Listenin son elemanını silin

# # del(list1[-1])

# # result = list1

# # 11- Liste elemanlarını tersten yazdırın

# result = list1[::-1]

# # 12- Aşağıdaki verileri bir liste içinde saklayınız
#      # studentA: Yiğit Bilgi 2010, (70,60,70)
#      # studentB: Sena Turan 1999, (80,80,70)
#      # studentC: Ahmet Turan 1998, (80,70,90)


# studentA = ['Yiğit','Bilgi' , 2010 , [70,60,70]]
# studentB = ['Sena','Turan' , 1999 , [80,80,70]]
# studentC = ['Ahmet' , 'Turan' , 1998 , [80,70,90]]

# # 13- Liste elemanlarını ekrana yazdırınız

# # result = studentA[0]
# # result = studentB[1]
# # result = studentC[3][1]


# result = f"{studentA[0]} {studentA[1]} {2019- studentA[2]} yaşında ve not ortalaması {(studentA[3][0] + studentA[3][1] + studentA[3][2])/3}  "

# print(result)

# %%
# Liste Metotları

# numbers = [1, 10, 5, 16, 4, 9, 10]
# letters = ['a', 'g', 's', 'b', 'y', 'a', 's']

# val = min(numbers)
# val = max(numbers)
# val = max(letters)
# val = min(letters)

# val = numbers[3:6]
# val = numbers[:3]
# val = numbers[4:]

# print(val)

# numbers[4] = 40
# numbers.append(49) #eleman eklemek istediğimizde kullanırız
# numbers.insert(3, 78) #3. indexten bir öncekine eleman ekler
# numbers.insert(-1, 52) #en sondaki index numarasından bir önceye ekler
# # numbers.pop() #en sondaki elemanı siler
# # numbers.pop(0) #0. indexteki elemanı siler
# numbers.remove(49) #yazılan elemanı siler
# # numbers.sort() #liste sayısal büyüklük olarak sıralanır
# # letters.sort() #alfabetik sıralanır
# numbers.reverse() #listeyi tersten yazar
# letters.reverse() #listeyi tersten yazar

# print(numbers)
# print(letters)

# print(len(numbers)) #kaç eleman var söyler
# print(len(letters))

# print(numbers.count(10)) #yazılı elemandan kaç tane olduğunu sayar
# print(letters.count('a'))


# numbers.clear() #bütün elemanları silmek için kullanılır
# print(numbers)

# %%
# Demo: Liste Metotları

# names = ['Ali', 'Yağmur', 'Hakan', 'Deniz']
# years = [1998, 2000, 1998, 1987]

# 1- "Cenk" ismini listenin sonuna ekleyiniz

# names.append('Cenk')
# print(names)

# # 2- "Sena" değerini listenin başına ekleyiniz

# names.insert(0, 'Sena')
# print(names)

# 3- "Deniz" ismini listeden siliniz

# names.pop(3)
# # names.remove('Deniz')
# print(names)

# # 4- "Deniz" isminin indeksi nedir?

# index = names.index('Deniz') #indexini bulmak için .index kullanırız
# print(index)

# 5- "Ali" listenin bir elemanı mıdır?

# result = 'Ali' in names
# print(result)

# 6- Liste elemanlarını ters çevirin

# names.reverse()
# print(names)

# 7- Liste elemanlarını alfabetik olarak sıralayınız

# names.sort()   # sırala
# names.sort(reverse=True)   # ters sırala
# names.sort(reverse=False)  # sırala

# print(names)

# 8- years listesini rakamsal büyüklüğe göre sıralayınız

# years.sort()
# print(years)

# 9- str = "Chevrolet, Dacia" karakter dizisini listeye çeviriniz

# str = "Chevrolet, Dacia"
# list = str.split(',')
# print(list)

# 10- years dizisinin en büyük ve en küçük elemanı nedir?

# val1 = min(years)
# val2 = max(years)

# print(val1, val2)

# 11- years dizisinde kaç tane 1998 değeri vardır?

# result = years.count(1998)
# print(result)

# 12- years dizisinin tüm elemanlarını siliniz

# years.clear()
# print(years)

# 13- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız
# marka1 = input("1. markayı giriniz: ")
# marka2 = input("2. markayı giriniz: ")
# marka3 = input("3. markayı giriniz: ")

# list = [marka1,  marka2 , marka3]
# print(list)

# %%
# #Tuple

# list = [1, 2, 3]

# tuple = (1, 'iki', 3)

# print(type(list))
# print(type(tuple))

# print(list[2])
# print(tuple[2])

# print(len(tuple))
# print(len(list))

# list = ['ali', 'veli']
# tuple = ('damla', 'ayşe', 'ayşe')
# names = ('demet', 'emel', 'ayşe') + tuple #bu sekilde toplama yapılabilir

# list[0] = 'ahmet' #0. indeksi ahmetle değiştirir
# # tuple[0] = 'deniz' #hata verir

# #tuple ve list cok benzer ama tek bir eleman uzerinde tupleda degisiklik yapamayız.


# print(tuple.count('ayşe'))
# print(tuple.index('ayşe'))

# print(list)
# print(tuple)
# print(names)

# %%
# Dictionary

# key - value

# sehirler = ['kocaeli', 'istanbul']
# plakalar = [41, 34]

# # result = plakalar[sehirler.index('kocaeli')]
# # result = plakalar[sehirler.index('istanbul')]
# # print(result)

# # print(plakalar['kocaeli]) => 41 amacımız

# plakalar = {'kocaeli' : 41 , 'istanbul' : 34}
# print(plakalar['kocaeli'])
# print(plakalar['istanbul'])

# plakalar['ankara'] = 6 #eklemek ya da değiştirmek için direkt böyle yazılabilir
# print(plakalar)

# users = {
#     'sadikturan' : {
#         'age': 36,
#         'roles' : ['user'],
#         'email': 'sadik@gmail.com',
#         'adress': 'kocaeli',
#         'phone' : '55264818451'
#     },
#     'cinarturan' : {
#         'age': 2,
#         'roles': ['admin', 'user'],
#         'email': 'cinar@gmail.com',
#         'adress': 'kocaeli',
#         'phone' : '55264818451'
#     }
# }

# print(users['cinarturan'])
# print(users['cinarturan']['email'])
# print(users['cinarturan']['roles'][0])

# %%
# Demo : Dictionary

# ogrenciler = {
#     "120": {"ad": "Ali", "soyad": "Yılmaz", "telefon": "532 000 00 00"},
#     "125": {"ad": "Can", "soyad": "Korkmaz", "telefon": "533 000 00 00"},
#     "128": {"ad": "Volkan", "soyad": "Yükselen", "telefon": "535 000 00 00"},
# }


# 1- Bilgileri verilen öğrencileri kullanıcıdan aldığınız bilgilerle dictionary içinde saklayınız

# 2- Öğrenci numarasını kullanıcıdan alıp ilgili öğrenci bilgisini gösterin.

# ogrenciler = {}

# number = input("öğrenci no: ")
# name = input("ogrenci adi: ")
# surname = input("ogrenci soyadi: ")
# phone = input("ogrenci telefon: ")

# ogrenciler[number] = {
#     'ad' : name,
#     'soyad': surname,
#     'telefon': phone
# }
# print(ogrenciler)

# number = input("öğrenci no: ")
# name = input("ogrenci adi: ")
# surname = input("ogrenci soyadi: ")
# phone = input("ogrenci telefon: ")

# ogrenciler.update({
#     number:{
#         'ad': name,
#         'soyad': surname,
#         'telefon': phone
#     }
# })

# number = input("öğrenci no: ")
# name = input("ogrenci adi: ")
# surname = input("ogrenci soyadi: ")
# phone = input("ogrenci telefon: ")


# ogrenciler.update({
#     number:{
#         'ad': name,
#         'soyad': surname,
#         'telefon': phone
#     }
# })

# number = input("öğrenci no: ")
# name = input("ogrenci adi: ")
# surname = input("ogrenci soyadi: ")
# phone = input("ogrenci telefon: ")


# ogrenciler.update({
#     number:{
#         'ad': name,
#         'soyad': surname,
#         'telefon': phone
#     }
# })

# print(ogrenciler)


# ogrNo = input('istediğiniz öğrenci no: ')
# ogrenci = ogrenciler[ogrNo]
# print(ogrenci)

# %%
# Sets

# fruits = {'orange', 'apple', 'banana'}

# print(fruits[0])  #indekslenemez

# for x in fruits:
#     print(x)
    
#sıralanamaz
    
# fruits.add('cherry') #eklemek için
# fruits.update(['mango' , 'grape', 'apple'])  #liste eklemek için kullanılır, zaten olan bir eleman tekrar eklenmez
# fruits.remove('mango') #kaldırmak için kullanılır
# fruits.discard('apple') #silmek için kullanılır
# fruits.pop()  #herhangi bir elemanı silebilir
# fruits.clear()

# print(fruits)

# myList = [1, 2, 5, 4, 4, 2, 1]

# print(set(myList))   # her elemandan sadece bir tane olur

# %%
# # Value &  Reference Types

# # value types => string, number

# x = 5
# y = 25

# x = y

# y = 10

# # print(x,y) # yde yapılan bir değişiklik xi etkilemez

# # reference types => list

# a = ["apple" , "banana"] 
# b = ["apple" , "banana"] 

# a = b

# b[0] = "grape"

# print(a, b) #yde yapılan değişiklik xi etkiler
# Out:
# ['grape', 'banana'] ['grape', 'banana']
