# %%
# If ve Else Blokları

# if 3>2:  #eğer 3 2den büyükse yazdır
#     print("Hoş geldiniz")

# if True:
#     print('Hoş  geldiniz')
        
# if False:
#     print('Hoş geldiniz')
    
# isLoggedin = True
# if True:
#     print('hoş geldiniz')       
    
    
# username = 'sadikturan'
# password = '1234'

# # isLoggedin = (username == 'sadikturan' and password == '1234')

# # if isLoggedin:
# #     print('Hoşgeldiniz')    
    
# # else:
# #     print('username ya da parola yanlış') 
    
# #ayrı ayrı öğrenmek için

# if (username == 'sadikturan' ):
#     if (password == '1234'):
#          print('Hoşgeldiniz')    
#     else:
#         print('Parola yanlış')     
    
# else:
#     print('username yanlış')

# %%
# Elif Komutu

# x = int(input('x: '))
# y = int(input('y: '))

# if x > y: 
#     print('x yden büyük')
# elif x == y:
#     print('x y eşit')    
# else:
#     print('y xden büyük')       


# num = int(input('sayi: '))

# if num > 0:
#     print('sayi pozitiftir')
# elif num < 0:
#     print('sayı negatif')
# else:
#     print('sayı sıfır')

# %%
# Demo : if else ve elif

#1
# isim = input('isim: ')
# yas = int(input('yaş: '))
# egitim = input('egitim: ')

# if yas > 18:
#     if egitim == 'lise' or egitim =='universite':
#         print('ehliyet alabilir')
#     else:
#         print('egitim durumunuzdan dolayı ehliyet alamazsınız')    
# else:
#     print('ehliyet alamazsınız yastan dolayı')    
 
#2
# yazili1 = int(input('1. yazılı:'))
# yazili2 = int(input('2. yazılı:'))
# sozlu = int(input('sozlu:'))

# ortalama = (yazili1+yazili2+sozlu)/3

# if (ortalama>0 ) and (ortalama<25) : 
#     print(f'ortalamanız : {ortalama} ve notunuz 0')
# elif (ortalama>=25 ) and (ortalama<44) : 
#     print(f'ortalamanız : {ortalama} ve notunuz 1') 
# elif (ortalama>=45 ) and (ortalama<54) : 
#     print(f'ortalamanız : {ortalama} ve notunuz 2') 
# elif (ortalama>=55 ) and (ortalama<69) : 
#     print(f'ortalamanız : {ortalama} ve notunuz 3') 
# elif (ortalama>=70 ) and (ortalama<84) : 
#     print(f'ortalamanız : {ortalama} ve notunuz 4')    
# elif (ortalama>=85 ) and (ortalama<=100) : 
#     print(f'ortalamanız : {ortalama} ve notunuz 5') 
# else:
#     print('yanlıs bilgi girdiniz')

#3

# from datetime import datetime
# tarih=input('aracınız hangi tarihte trafige cıktı(yyyy/aa/gg): ')
# tarih = tarih.split('/')

# trafigeCikis = datetime(int(tarih[0]), int(tarih[1]), int(tarih[2]))
# simdi = datetime.now()


# fark = simdi - trafigeCikis
# days=fark

# print (fark.days)
# if days<=365:
#     print('1. servis aralıgı')
# elif days>365 and days<=730:
#     print('2. servis aralıgı')
# elif days>730 and days<=1095:
#     print('3. servis aralıgı')

# %%
# Demo : Koşul ifadeleri

#1

# sayi = float(input('sayi giriniz'))

# if sayi > 0 and sayi < 100:
#     print('sayi 0-100 arasinda')
# else:
#     print('sayi 0-100 arasinda degildir')    

#2
# sayi = float(input('sayi giriniz'))

# if sayi % 2 ==0:
#     print('sayi çift')
# else:
#     print('sayi çift degildir')   

#3

# email = 'email.sadikturan.com'
# password = '1234'

# girilenEmail = input('email: ')
# girilenSifre = input('sifre: ')

# if girilenEmail == email:
#     if girilenSifre == password:
#         print('hosgeldiniz')
#     else:
#         print('sifre yanlis')
# else:
#     print('email yanlis')            


#4 

# a = int(input('a: '))
# b = int(input('b: '))
# c = int(input('c: '))

# if a>b and a>c:
#     print('a en büyük sayıdır')
# elif b>a and b>c:
#     print(' b en büyük sayıdır')
# elif c>a and c>b:
#     print(' c en büyük sayıdır')   
# else: 
#     print('yanlis deger girdiinz')

#5

# vize1 = float(input('1. vize: '))
# vize2 = float(input('2. vize: '))
# final = float(input('final: '))

# ortalama = (vize1+vize2) / 2 * 0.6 + final * 0.4

# if ortalama > 50:
#     if final > 50:
#         print('gecti')
#     else:    
#         print('kaldi')
# else:
#     print('kaldi')


# if ortalama > 50:
#     print('gecti')
# else:
#     if final > 70:
#         print('gecti')
#     else:
#         print('kaldi')

#6

# name = input('isim: ')
# kg = int(input('kg: '))
# hg = int(input('hg: '))

# index  = kg /(hg ** 2)

# if index > 0 and index <18.4:
#     print ('zayif')
# elif index > 18.5 and index <24.9:
#     print ('normal')
# elif index > 25.0 and index <29.9:
#     print ('fazla kilolu')    
# elif index > 30 and index <34.9:
#     print ('obez')
# Out:
# zayif
